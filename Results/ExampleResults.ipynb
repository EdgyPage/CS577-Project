# %%
import analyze as a

# %%
genderPairs = a.genderPairs('GenderPairs.csv')
spotlightWords = a.spotlightWords('Spotlight.csv')

# %%
testGEmbed = a.embeds('GvectorsBUG.txt')
testNEmbed = a.embeds('NvectorsBUG.txt')

# %%
a.distanceVector(spotlightWords, genderPairs, testGEmbed)
a.distanceVector(spotlightWords, genderPairs, testNEmbed)

# %%
a.plotter(genderPairs, spotlightWords, testNEmbed, testGEmbed, ['vagina', 'nurse'])
